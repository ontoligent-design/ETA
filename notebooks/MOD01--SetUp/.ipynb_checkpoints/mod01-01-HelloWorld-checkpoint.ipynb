# %%
x = 'hello, world!'

# %%
x
# Out:
# 'hello, world!'

# %%
print(x)
# Out:
# hello, world!

# %%
def hello(name):
    print("Hello, " + name)

# %%
hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a75d7781aaeb> in <module>()
# ----> 1 hello()
#
# TypeError: hello() missing 1 required positional argument: 'name'

# %%
hello(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1f805eb1b77d> in <module>()
# ----> 1 hello(1)
#
# <ipython-input-4-5cee79b67824> in hello(name)
#       1 def hello(name):
# ----> 2     print("Hello, " + name)
#
# TypeError: must be str, not int

# %%
hello("Raf")
# Out:
# Hello, Raf

# %%
hello("Susan")
# Out:
# Hello, Susan

# %%
hello("Ravi")
# Out:
# Hello, Ravi

# %%
hello("Jin")
# Out:
# Hello, Jin
