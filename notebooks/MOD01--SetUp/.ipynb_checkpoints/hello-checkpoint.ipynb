# %% [markdown]
# # Hello World!

# %%
"Hello, World!"
# Out:
# 'Hello, World!'

# %%
x = "Hello, World!"

# %%
x
# Out:
# 'Hello, World!'

# %%
print(x)
# Out:
# Hello, World!

# %%
print("Hello, World Raf!")
# Out:
# Hello, World Raf!

# %%
print("Hello Raf!")
# Out:
# Hello Raf!

# %%
print("Hello Quetzil!")
# Out:
# Hello Quetzil!

# %%
def hello(fname=''):
    print("Hello " + fname + "!")

# %%
hello("Raf")
# Out:
# Hello Raf!

# %%
hello("Quetzil!")
# Out:
# Hello Quetzil!!
