# %%
import pandas as pd
import glob
import re
import xml.etree.ElementTree as ET
import requests

# %%
gut_url = 'https://www.gutenberg.org/ebooks/{}'
gut_txt = 'https://www.gutenberg.org/ebooks/{}.txt.utf-8'

data_dir = '/home/rca2t/Public/ETA/data/gutenberg/cache/epub'
epub_path = data_dir + '/{0}/pg{0}.rdf'
TAG = re.compile(r'<[^>]+>')

# %%
gids = [int(path.split('/')[-1]) for path in glob.glob(data_dir+'/*')]
gids = sorted(gids)

# %%
df = pd.DataFrame(gids,  columns=['gut_id'])
df = df.set_index('gut_id')

# %% [markdown]
# # XML Processing

# %%
ns = dict(base="http://www.gutenberg.org/",
    rdfs="http://www.w3.org/2000/01/rdf-schema#",
    rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#",
    marcrel="http://id.loc.gov/vocabulary/relators/",
    pgterms="http://www.gutenberg.org/2009/pgterms/",
    cc="http://web.resource.org/cc/",
    dcam="http://purl.org/dc/dcam/",
    dcterms="http://purl.org/dc/terms/")

# %%
xpaths = dict(
    subjects = ".//dcterms:subject/rdf:Description/rdf:value",
    bookshelves = ".//pgterms:bookshelf/rdf:Description/rdf:value",
    languages = ".//dcterms:language/rdf:Description/rdf:value",
    agents = ".//marcrel:ill/pgterms:agent/pgterms:name",
    rights = ".//dcterms:rights",
    title = ".//dcterms:title",
    types = ".//dcterms:type/rdf:Description/rdf:value",
    creators = ".//dcterms:creator/pgterms:agent/pgterms:name",
    formats = ".//dcterms:hasFormat/pgterms:file/dcterms:format/rdf:Description/rdf:value"
)

# %%
default_format='text/plain; charset=utf-8'

# %%
for item in xpaths:
    df[item] = None

# %%
def get_rdf(gut_id, data_dir=data_dir):
    path = "{0}/{1}/pg{1}.rdf".format(data_dir, gut_id)
    rdf = open(path, 'r').read()
    return rdf

# %%
def get_text_url(gut_id):
    gut_txt = 'https://www.gutenberg.org/ebooks/{}.txt.utf-8'.format(gut_id)
    return gut_txt

# %%
def get_text_content(gut_id):
    gut_url = get_text_url(gut_id)
    r = requests.get(gut_url)
    return r.text

# %%
def get_items(el, xpath, ns=ns):
    items = [item.text for item in el.findall(xpath, namespaces=ns)]
    return items

# %%
def get_rdf_root(gut_id):
    rdf = get_rdf(gut_id)
    root = ET.fromstring(rdf)
    return root

# %%
def is_text(formats, default_format='text/plain; charset=utf-8'):
    return

# %%
def get_metadata(gut_id):
    rdf_root = get_rdf_root(gut_id)
    md = {}
    for item in xpaths:
        md[item] = get_items(rdf_root, xpaths[item])
    return md

# %%
md = get_metadata(10036)

# %%
md
# Out:
# {'subjects': ['American wit and humor -- Periodicals', 'AP'],
#  'bookshelves': ['Punchinello'],
#  'languages': ['en'],
#  'agents': [],
#  'rights': ['Public domain in the USA.'],
#  'title': ['Punchinello, Volume 2, No. 28, October 8, 1870'],
#  'types': ['Text'],
#  'creators': ['Various'],
#  'formats': ['text/html; charset=iso-8859-1',
#   'application/zip',
#   'application/zip',
#   'text/plain; charset=iso-8859-1',
#   'text/html; charset=iso-8859-1',
#   'application/x-mobipocket-ebook',
#   'application/rdf+xml',
#   'text/plain',
#   'text/plain; charset=iso-8859-1',
#   'text/plain; charset=us-ascii',
#   'application/zip',
#   'text/plain; charset=us-ascii',
#   'application/epub+zip',
#   'application/epub+zip',
#   'application/x-mobipocket-ebook']}

# %%
def get_data(x):
    gut_id = x.name
    md = get_metadata(gut_id)
    for item in xpaths:
        x[item] = md[item]
    return x

# %%
def populate_df():
    df = pd.DataFrame(gids,  columns=['gut_id'])
    df = df.set_index('gut_id')
    for item in xpaths:
        df[item] = None
    df = df.apply(get_data, axis=1)
    df.title = df.title.str.replace('&#13;', '')
    return df

# %%
df = populate_df()

# %%
df.head()
# Out:
#                                                  subjects  \
# gut_id
# 0                                                      []
# 1       [United States. Declaration of Independence, E...
# 2       [United States. Constitution. 1st-10th Amendme...
# 3       [Presidents -- United States -- Inaugural addr...
# 4       [Lincoln, Abraham, 1809-1865. Gettysburg addre...
#
#                                               bookshelves languages agents  \
# gut_id
# 0                                                      []        []     []
# 1       [American Revolutionary War, United States Law...      [en]     []
# 2       [United States Law, Politics, American Revolut...      [en]     []
# 3                                                      []      [en]     []
# 4                                          [US Civil War]      [en]     []
#
#                              rights  title   types  \
# gut_id
# 0       [Public domain in the USA.]    NaN  [Text]
# 1       [Public domain in the USA.]    NaN  [Text]
# 2       [Public domain in the USA.]    NaN  [Text]
# 3       [Public domain in the USA.]    NaN  [Text]
# 4       [Public domain in the USA.]    NaN  [Text]
#
#                                     creators  \
# gut_id
# 0                                         []
# 1                        [Jefferson, Thomas]
# 2                            [United States]
# 3       [Kennedy, John F. (John Fitzgerald)]
# 4                         [Lincoln, Abraham]
#
#                                                   formats
# gut_id
# 0                                                      []
# 1       [text/plain; charset=us-ascii, application/zip...
# 2       [text/plain; charset=us-ascii, application/rdf...
# 3       [application/epub+zip, application/x-mobipocke...
# 4       [text/plain, text/plain; charset=us-ascii, app...

# %%
data_dir2 = '/home/rca2t/Public/ETA/data/gutenberg'

# %%
import sqlite3

# %%
with sqlite3.connect(data_dir2 + '/gutenberg.db') as db:
    df.to_sql('title', db, index=True, if_exists='replace')

# %%
df
# Out:
#                                                     title  \
# gut_id
# 1       The Declaration of Independence of the United ...
# 2                   The United States Bill of Rights&#13;
# 3                     John F. Kennedy's Inaugural Address
# 4                       Lincoln's Gettysburg Address&#13;
# 5                          The United States Constitution
# 6                        Give Me Liberty or Give Me Death
# 7                                   The Mayflower Compact
# 8              Abraham Lincoln's Second Inaugural Address
# 9               Abraham Lincoln's First Inaugural Address
# 27                                    Hardy, Thomas
# 28                                            Aesop
# 29              United States. Bureau of the Census
# 30                                             none
# ...                                             ...
# 60262                           Lloyd George, David
# 60263                               Belloc, Hilaire
# 60264                              Bradley, Richard
# 60265                          Vandercook, Margaret
# 60266                                 Haahti, Hilja
# 60267                          Hecker, Isaac Thomas
# 60268                               Lafond, Georges
# 60269                         Fitzhugh, Percy Keese
# 60270             Verrill, A. Hyatt (Alpheus Hyatt)
# 60271                              Harrow, Benjamin
# 60272                            Cumberland, Gerald
# 60273                                Hueston, Ethel
# 60274                               Bellamy, Edward
# 60275                            Kellogg, Charlotte
# 60276                                   Barry, Iris
# 60277                          Zahm, Albert Francis
# 60278                                 Walpole, Hugh
# 60279                     Emerson, Nathaniel Bright
# 60280                         George, Walter Lionel
# 60281                             Engels, Friedrich
# 60282                                Christy, David
# 60283                              Fisher, David E.
# 60284                             Caballero, Fernán
# 60285             Filippini, Alessandro (Alexander)
# 60286                 Waller, A. R. (Alfred Rayney)
# 60287                  Järvi, K. A. (Kaarlo August)
# 60288                                       Various
# 60289                          Huxley, Thomas Henry
# 60290                           Biddulph, J. (John)
# 999999                               Serao, Matilde
#
#                                                       rdf
# gut_id
# 1       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 2       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 3       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 4       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 5       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 6       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 7       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 8       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 9       <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 10      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 11      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 12      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 13      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 14      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 15      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 16      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 17      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 18      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 19      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 20      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 21      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 22      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 23      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 24      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 25      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 26      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 27      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 28      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 29      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 30      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# ...                                                   ...
# 60262   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60263   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60264   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60265   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60266   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60267   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60268   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60269   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60270   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60271   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60272   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60273   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60274   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60275   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60276   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60277   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60278   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60279   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60280   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60281   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60282   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60283   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60284   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60285   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60286   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60287   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60288   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60289   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 60290   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 999999  <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
#
# [60209 rows x 3 columns]

# %%
def get_works_by(name_pat):
    works = df.loc[df.creator.str.contains(name_pat)]
    return works

# %%
milton = get_works_by('Milton, John')

# %%
milton
# Out:
#                                                     title       creator  \
# gut_id
# 20                                          Paradise Lost  Milton, John
# 26                                          Paradise Lost  Milton, John
# 58                                      Paradise Regained  Milton, John
# 397           L'Allegro, Il Penseroso, Comus, and Lycidas  Milton, John
# 608                                          Areopagitica  Milton, John
# 6929    Poemata : Latin, Greek and Italian Poems by Jo...  Milton, John
# 19819                                      Milton's Comus  Milton, John
# 31706                                 Milton: Minor Poems  Milton, John
#
#                                                       rdf
# gut_id
# 20      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 26      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 58      <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 397     <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 608     <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 6929    <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 19819   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 31706   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...

# %%
austen = get_works_by('Austen, Jane')

# %%
austen
# Out:
#                                                     title       creator  \
# gut_id
# 105                                            Persuasion  Austen, Jane
# 121                                      Northanger Abbey  Austen, Jane
# 141                                        Mansfield Park  Austen, Jane
# 158                                                  Emma  Austen, Jane
# 161                                 Sense and Sensibility  Austen, Jane
# 946                                            Lady Susan  Austen, Jane
# 1212                            Love and Freindship [sic]  Austen, Jane
# 1342                                  Pride and Prejudice  Austen, Jane
# 19839                                                Emma  Austen, Jane
# 20682                                    Northanger Abbey  Austen, Jane
# 20686                                 Pride and Prejudice  Austen, Jane
# 20687                                 Pride and Prejudice  Austen, Jane
# 21839                               Sense and Sensibility  Austen, Jane
# 22953                                          Lady Susan  Austen, Jane
# 22954                           Love and Freindship [sic]  Austen, Jane
# 22962                                      Mansfield Park  Austen, Jane
# 22963                                          Persuasion  Austen, Jane
# 22964                               Sense and Sensibility  Austen, Jane
# 25946                                  Gevoel en verstand  Austen, Jane
# 26301                                 Pride and Prejudice  Austen, Jane
# 31100   The Complete Project Gutenberg Works of Jane A...  Austen, Jane
# 33388   Raison et sensibilité, ou les deux manières d'...  Austen, Jane
# 35163   Raison et sensibilité, ou les deux manières d'...  Austen, Jane
# 37431   Pride and Prejudice, a play founded on Jane Au...  Austen, Jane
# 37634   Raison et sensibilité, ou les deux manières d'...  Austen, Jane
# 42671                                 Pride and Prejudice  Austen, Jane
# 43741   Old Friends and New Fancies: An Imaginary Sequ...  Austen, Jane
#
#                                                       rdf
# gut_id
# 105     <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 121     <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 141     <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 158     <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 161     <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 946     <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 1212    <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 1342    <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 19839   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 20682   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 20686   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 20687   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 21839   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 22953   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 22954   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 22962   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 22963   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 22964   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 25946   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 26301   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 31100   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 33388   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 35163   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 37431   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 37634   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 42671   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...
# 43741   <?xml version="1.0" encoding="utf-8"?>\n<rdf:R...

# %%
import requests

# %%
download_dir = '/home/rca2t/Public/ETA/data/gutenberg/downloads'

# %%
def download_works(works, download_dir=download_dir):
    gids = works.index.tolist()
    for gid in gids:
        print(gid)
        url = 'https://www.gutenberg.org/ebooks/{}.txt.utf-8'.format(gid)
        r = requests.get(url)
        with open(download_dir+"/g{}.txt".format(gid), 'w', encoding='utf8') as out:
            out.write(r.text)

# %%
works = download_works(austen)
# Out:
# 105
# 121
# 141
# 158
# 161
# 946
# 1212
# 1342
# 19839
# 20682
# 20686
# 20687
# 21839
# 22953
# 22954
# 22962
# 22963
# 22964
# 25946
# 26301
# 31100
# 33388
# 35163
# 37431
# 37634
# 42671
# 43741

# %%
milton.groupby('title').count()
# Out:
#                                                     creator  rdf
# title
# Areopagitica                                              1    1
# L'Allegro, Il Penseroso, Comus, and Lycidas               1    1
# Milton's Comus                                            1    1
# Milton: Minor Poems                                       1    1
# Paradise Lost                                             2    2
# Paradise Regained                                         1    1
# Poemata : Latin, Greek and Italian Poems by Joh...        1    1

# %%
milton.rdf.str.contains('audio')
# Out:
# gut_id
# 20       False
# 26       False
# 58       False
# 397      False
# 608      False
# 6929     False
# 19819    False
# 31706    False
# Name: rdf, dtype: bool
